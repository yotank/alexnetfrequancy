# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.applications.vgg16 import VGG16
model = VGG16(include_top=True, weights='imagenet', input_tensor=None, input_shape=None)

# %%
print(model)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
model.save_weights('weight.json',encoding='utf8')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-8eb0437144a6> in <module>()
# ----> 1 model.save_weights('weight.json',encoding='utf8')
#
# TypeError: save_weights() got an unexpected keyword argument 'encoding'

# %%
weights = model.get_weights()

# %%
print(weights)
# Out:
# [array([[[[ 4.29470569e-01,  1.17273867e-01,  3.40129584e-02, ...,
#           -1.32241577e-01, -5.33475243e-02,  7.57738389e-03],
#          [ 5.50379455e-01,  2.08774377e-02,  9.88311544e-02, ...,
#           -8.48205537e-02, -5.11389151e-02,  3.74943428e-02],
#          [ 4.80015397e-01, -1.72696680e-01,  3.75577137e-02, ...,
#           -1.27135560e-01, -5.02991639e-02,  3.48965675e-02]],
#
#         [[ 3.73466998e-01,  1.62062630e-01,  1.70863140e-03, ...,
#           -1.48207128e-01, -2.35300660e-01, -6.30356818e-02],
#          [ 4.40074533e-01,  4.73412387e-02,  5.13819456e-02, ...,
#           -9.88498852e-02, -2.96195745e-01, -7.04357103e-02],
#          [ 4.08547401e-01, -1.70375049e-01, -4.96297423e-03, ...,
#           -1.22360572e-01, -2.76450396e-01, -3.90796512e-02]],
#
#         [[-6.13601133e-02,  1.35693997e-01, -1.15694344e-01, ...,
#           -1.40158370e-01, -3.77666801e-01, -3.00509870e-01],
#          [-8.13870355e-02,  4.18543853e-02, -1.01763301e-01, ...,
# ...

# %%
len(weights)
# Out:
# 32

# %%
import numpy as np
arr_weights = np.array(weights)

# %%
print(arr_weights)
# Out:
# [array([[[[ 4.29470569e-01,  1.17273867e-01,  3.40129584e-02, ...,
#           -1.32241577e-01, -5.33475243e-02,  7.57738389e-03],
#          [ 5.50379455e-01,  2.08774377e-02,  9.88311544e-02, ...,
#           -8.48205537e-02, -5.11389151e-02,  3.74943428e-02],
#          [ 4.80015397e-01, -1.72696680e-01,  3.75577137e-02, ...,
#           -1.27135560e-01, -5.02991639e-02,  3.48965675e-02]],
#
#         [[ 3.73466998e-01,  1.62062630e-01,  1.70863140e-03, ...,
#           -1.48207128e-01, -2.35300660e-01, -6.30356818e-02],
#          [ 4.40074533e-01,  4.73412387e-02,  5.13819456e-02, ...,
#           -9.88498852e-02, -2.96195745e-01, -7.04357103e-02],
#          [ 4.08547401e-01, -1.70375049e-01, -4.96297423e-03, ...,
#           -1.22360572e-01, -2.76450396e-01, -3.90796512e-02]],
#
#         [[-6.13601133e-02,  1.35693997e-01, -1.15694344e-01, ...,
#           -1.40158370e-01, -3.77666801e-01, -3.00509870e-01],
#          [-8.13870355e-02,  4.18543853e-02, -1.01763301e-01, ...,
# ...

# %%
print(len(arr_weights))
# Out:
# 32

# %% [markdown]
# 各行の数が異なる多重配列のため.shapeではうまくいかない(32,)とs表示される

# %%
print(arr_weights[0])
# Out:
# [[[[ 4.29470569e-01  1.17273867e-01  3.40129584e-02 ... -1.32241577e-01
#     -5.33475243e-02  7.57738389e-03]
#    [ 5.50379455e-01  2.08774377e-02  9.88311544e-02 ... -8.48205537e-02
#     -5.11389151e-02  3.74943428e-02]
#    [ 4.80015397e-01 -1.72696680e-01  3.75577137e-02 ... -1.27135560e-01
#     -5.02991639e-02  3.48965675e-02]]
#
#   [[ 3.73466998e-01  1.62062630e-01  1.70863140e-03 ... -1.48207128e-01
#     -2.35300660e-01 -6.30356818e-02]
#    [ 4.40074533e-01  4.73412387e-02  5.13819456e-02 ... -9.88498852e-02
#     -2.96195745e-01 -7.04357103e-02]
#    [ 4.08547401e-01 -1.70375049e-01 -4.96297423e-03 ... -1.22360572e-01
#     -2.76450396e-01 -3.90796512e-02]]
#
#   [[-6.13601133e-02  1.35693997e-01 -1.15694344e-01 ... -1.40158370e-01
#     -3.77666801e-01 -3.00509870e-01]
#    [-8.13870355e-02  4.18543853e-02 -1.01763301e-01 ... -9.43124294e-02
#     -5.05662560e-01 -3.83694321e-01]
#    [-6.51455522e-02 -1.54351532e-01 -1.38038069e-01 ... -1.29404560e-01
# ...

# %%
print(arr_weights[0][0])
# Out:
# [[[ 0.42947057  0.11727387  0.03401296  0.35422093 -0.0865837
#     0.22968295  0.06683242  0.04133838  0.13026784  0.03291035
#     0.09615457 -0.09222532 -0.15587331  0.0522968  -0.08324417
#     0.15728769  0.0291196   0.05094835  0.19055748 -0.04372229
#     0.3618031   0.23902874  0.16667192 -0.18046746  0.04404821
#     0.09592837 -0.04381131 -0.1884835  -0.04399502 -0.18985446
#    -0.23386982  0.12836744 -0.11059975  0.00571336 -0.24479656
#    -0.30530283  0.060938   -0.32816252  0.1711953   0.10265407
#    -0.11063665  0.33012986 -0.05869728  0.18478717  0.01050853
#     0.10668027 -0.13086924 -0.36283946  0.06440807  0.09335972
#     0.00401619  0.37814805  0.05268804 -0.27078936  0.11060741
#    -0.11819526  0.04298935  0.35323623 -0.28468162 -0.20289008
#    -0.284944   -0.13224158 -0.05334752  0.00757738]
#   [ 0.55037946  0.02087744  0.09883115  0.43703237 -0.10985146
#    -0.19237703  0.09789737  0.07935189 -0.2751774  -0.14232883
# ...

# %%
print(arr_weights[0].shape)
# Out:
# (3, 3, 3, 64)

# %%
arr_weights[0].shape
# Out:
# (3, 3, 3, 64)

# %%
arr_weights[0][1][2][1][32]
# Out:
# -0.0613196

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png')
#構造の可視化

# %%
for ii in range(len(arr_weights)):
    print(ii)
    print(arr_weights[ii].shape)
# Out:
# 0
# (3, 3, 3, 64)
# 1
# (64,)
# 2
# (3, 3, 64, 64)
# 3
# (64,)
# 4
# (3, 3, 64, 128)
# 5
# (128,)
# 6
# (3, 3, 128, 128)
# 7
# (128,)
# 8
# (3, 3, 128, 256)
# 9
# (256,)
# 10
# (3, 3, 256, 256)
# 11
# (256,)
# 12
# (3, 3, 256, 256)
# 13
# (256,)
# 14
# (3, 3, 256, 512)
# 15
# (512,)
# 16
# (3, 3, 512, 512)
# 17
# (512,)
# 18
# (3, 3, 512, 512)
# 19
# (512,)
# 20
# (3, 3, 512, 512)
# 21
# (512,)
# 22
# (3, 3, 512, 512)
# 23
# (512,)
# 24
# (3, 3, 512, 512)
# 25
# (512,)
# 26
# (25088, 4096)
# 27
# (4096,)
# 28
# (4096, 4096)
# 29
# (4096,)
# 30
# (4096, 1000)
# 31
# (1000,)

# %%
print(arr_weights[1])
# Out:
# [ 0.73429835  0.09340367  0.06775674  0.8862966   0.25994542  0.66426694
#  -0.01582893  0.3249065   0.68600726  0.06247932  0.58156496  0.2361475
#   0.69694996  0.19451167  0.4858922   0.44571847  0.5113422   0.208576
#   0.57557714  0.33199573  0.4997983   0.7117759   0.30284074  0.7082712
#   0.04548979  0.7446502   0.29845494  0.48211655  0.81658626  0.62603897
#   0.3768093   2.064037    0.77311045  0.3459577   0.6130958   0.65459156
#   0.39045632  0.50869167  0.2625384   0.23669638  0.07971057  1.1179353
#   0.26129362  0.8697589   0.21543622  0.78007823  0.37015367  0.47993386
#   0.4313978   0.5084194   0.23049663  0.7636527   0.35419866  0.45794216
#   0.4662595   0.09850298  0.3803252   0.66880196  0.4015123   0.90510356
#   0.43166816  1.302014    0.5306885   0.48993504]

# %%
plot_model(model, to_file='vgg16.png', show_shapes=True)

# %% [markdown]
# #一層目のフィルターを表示する

# %%
#一層目の重みとバイアスを取り出す

first_layer_weight = arr_weights[0]
print(first_layer_weight.shape)
first_layer_bias = arr_weights[1]
print(first_layer_bias.shape)
# Out:
# (3, 3, 3, 64)
# (64,)

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# sphinx_gallery_thumbnail_number = 2

vegetables = ["cucumber", "tomato", "lettuce", "asparagus",
              "potato", "wheat", "barley"]
farmers = ["Farmer Joe", "Upland Bros.", "Smith Gardening",
           "Agrifun", "Organiculture", "BioGoods Ltd.", "Cornylee Corp."]

harvest = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                    [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
                    [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
                    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])


fig, ax = plt.subplots()
im = ax.imshow(harvest)

# We want to show all ticks...
ax.set_xticks(np.arange(len(farmers)))
ax.set_yticks(np.arange(len(vegetables)))
# ... and label them with the respective list entries


# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), ha="right",rotation_mode="anchor")

fig.colorbar(im)

# Loop over data dimensions and create text annotations.
for i in range(len(vegetables)):
    for j in range(len(farmers)):
        text = ax.text(j, i, harvest[i, j],ha="center", va="center", color="w")

ax.set_title("Harvest of local farmers (in tons/year)")
fig.tight_layout()
plt.show()

# %%
def draw_heatmap(data, row_labels, column_labels):
    # 描画する
    fig, ax = plt.subplots()
    heatmap = ax.pcolor(data, cmap=plt.cm.binary)

    ax.set_xticks(np.arange(data.shape[0]) + 0.5, minor=False)
    ax.set_yticks(np.arange(data.shape[1]) + 0.5, minor=False)

    ax.invert_yaxis()
    ax.xaxis.tick_top()

    ax.set_xticklabels(row_labels, minor=False)
    ax.set_yticklabels(column_labels, minor=False)
   # fig.colorbar()
    plt.show()
    plt.savefig('image.png')

    return heatmap

# %%
a=np.array([[2,4,3],[2,3,1],[10,2,3]])

draw_heatmap(a,"","")

# %%
plt.figure(figsize=(20,20))
a=np.array([[2,4,3],[2,3,1],[10,2,3]])

draw_heatmap(a,"","")

# %%
target_layer_weight = first_layer_weight
fig = plt.figure(figuresize=(20,20))


for filta in range(len(target_layer_weight[0,0,0,:])):
for channel in range(len(target_layer_weight[0,0,:,0])):
        th= filta*4 + (chanel+1)
        data = first_layer_weight[:,:,channel,filter]
        ax = fig.add_subplot(2,2,th)
        heatmap = ax.pcolor(data, cmap=plt.cm.binary)
        ax.set_xticks(np.arange(data.shape[0]) + 0.5, minor=False)
ax.set_yticks(np.arange(data.shape[1]) + 0.5, minor=False)

    ax.invert_yaxis()
    ax.xaxis.tick_top()

    ax.set_xticklabels(row_labels, minor=False)
    ax.set_yticklabels(column_labels, minor=False)
    
    
        plt.show()
    plt.savefig('image.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-45e872c5dfeb> in <module>()
#       1
#       2
# ----> 3 target_layer_weight = first_layer_weight
#       4 fig = plt.figure(figuresize=(20,20))
#       5
#
# NameError: name 'first_layer_weight' is not defined

# %%
print(first_layer_weight[:,:,1,30])

print(len(first_layer_weight[0,0,:,0]))
    
for ii in range(3):
    print(ii)
# Out:
# [[-0.2635083  -0.16567972 -0.07209669]
#  [-0.09885683  0.2213829   0.20242453]
#  [ 0.00267146  0.2615135   0.21539773]]
# 3
# 0
# 1
# 2

# %%
target_layer_weight = first_layer_weight



target_layer_weight_RGB_sum = target_layer_weight[:,:,0]+target_layer_weight[:,:,1]+target_layer_weight[:,:,2]
#(3,3,64)





fig = plt.figure(figsize=(6,6))
num_filta = len(target_layer_weight[0,0,0,:])
num_channel = len(target_layer_weight[0,0,:,0])
for filta in range(num_filta):
    for channel in range(num_channel):
        th= filta*4 + (channel+1)
        data = first_layer_weight[:,:,channel,filta]
        ax = data
        plt.subplot(num_filta+1,num_channel+1,th)
        #heatmap = ax.pcolor(data, cmap=plt.cm.binary)
        plt.plot(ax)
        #ax.set_xticklabels(row_labels, minor=False)
        #ax.set_yticklabels(column_labels, minor=False)
plt.show()
plt.savefig('image.png')

# %%
print(first_layer_weight[:,:,2,2])
# Out:
# [[ 0.03755771 -0.00496297 -0.13803807]
#  [ 0.16659534  0.15118818 -0.10984964]
#  [ 0.01562795 -0.00796698 -0.14913309]]

# %%
import numpy as np 
import seaborn as sns
 
# 10x12 の一様乱数を生成
np.random.seed(0)
uniform_data = np.random.rand(10, 12)
 
# ヒートマップを出力
sns.heatmap(uniform_data)

# %%
target_layer_weight_RGB_sum = target_layer_weight[:,:,0,:]+target_layer_weight[:,:,1,:]+target_layer_weight[:,:,2,:]
print(target_layer_weight_RGB_sum.shape)
# Out:
# (3, 3, 64)

# %%
#RGBの平均

target_layer_weight = first_layer_weight


target_layer_weight_RGB_sum = (target_layer_weight[:,:,0]+target_layer_weight[:,:,1]+target_layer_weight[:,:,2])/3
#(3,3,64)


fig = plt.figure(figsize=(18,18))
fig.suptitle('VGG16_1st_layer_filter_mean(3cannels).png',fontsize=18)
num_filta = len(target_layer_weight[0,0,0,:])

for filta in range(num_filta):
    data = target_layer_weight_RGB_sum[:,:,filta]
    plt.subplot(10,7,filta+1)  
    plt.imshow(data,cmap="gray")
    plt.subplots_adjust(wspace=0.3,hspace=0.3)
    plt.xticks([],[])
    plt.yticks([],[])

    
        #heatmap = ax.pcolor(data, cmap=plt.cm.binary)
        
        #ax.set_xticklabels(row_labels, minor=False)
        #ax.set_yticklabels(column_labels, minor=False)
#plt.show()
plt.savefig('VGG16_1st_layer_filter_mean(3cannels).png')
plt.show()

# %%
for ii in range(64):
    print(target_layer_weight_RGB_sum[:,:,ii])
# Out:
# [[ 1.4598655   1.2220889  -0.2078927 ]
#  [ 0.93098617  0.12951535 -1.2241081 ]
#  [-0.16697477 -0.8781469  -1.2536433 ]]
# [[-0.03454538  0.03902882  0.02319685]
#  [-0.00820196  0.0905371   0.03354594]
#  [-0.00497961  0.05961579  0.02398123]]
# [[ 0.17040184  0.0481276  -0.35549572]
#  [ 0.5689057   0.52791387 -0.26653   ]
#  [ 0.1044898   0.04076724 -0.3865492 ]]
# [[ 1.2000287   0.91590756  0.9972475 ]
#  [ 0.29370716 -1.1814528  -0.19680372]
#  [-0.07653968 -1.3868153  -0.57477754]]
# [[-0.27846885  0.6818073   0.63754416]
#  [-0.6018933   0.62575084  0.5928957 ]
#  [-0.8544305  -0.43646827 -0.2803488 ]]
# [[-0.01097484 -0.07028665  0.00160399]
#  [-0.030582   -0.07169873 -0.06683322]
#  [-0.01335906  0.00617326 -0.01988485]]
# [[ 0.23034817 -0.3846175  -0.58756316]
#  [ 0.50347763 -0.17158574 -0.52689683]
#  [ 0.56484705  0.34411162  0.03179561]]
# [[ 0.23868755  0.5846853   0.6012393 ]
#  [-0.6139209  -0.29143822  0.3580132 ]
#  [-0.71689546 -0.51310366  0.13373001]]
# ...

# %%
#RGBそれぞれ


#(3,3,3,64)


fig = plt.figure(figsize=(18,18))
num_filta = len(target_layer_weight[0,0,0,:])
num_channel = len(target_layer_weight[0,0,:,0])

for channel in range(num_channel):
    fig = plt.figure(figsize=(18,18))
    fig.suptitle('VGG16_1st_layer_filter_channel:'+str(channel)+'.png',fontsize=18)
    for filta in range(num_filta):
        data = target_layer_weight[:,:,channel,filta]
        plt.subplot(10,7,filta+1)  
        plt.imshow(data,cmap="gray")
        plt.subplots_adjust(wspace=0.3,hspace=0.3)
        plt.xticks([],[])
        plt.yticks([],[])
        if filta == num_filta-1:
            plt.savefig('VGG16_1st_layer_filter_channel:'+str(channel)+'.png')

    
        #heatmap = ax.pcolor(data, cmap=plt.cm.binary)
        
        #ax.set_xticklabels(row_labels, minor=False)
        #ax.set_yticklabels(column_labels, minor=False)
#plt.show()

plt.show()

# %%
# Out:
# (3, 3, 3, 64)

# %%
first_layer_weight.min()
# Out:
# -0.67140007

# %%
fig = plt.figure(figsize=(18,18))
num_filta = len(target_layer_weight[0,0,0,:])
num_channel = len(target_layer_weight[0,0,:,0])

data = np.array([[-8,3,4],[0,1,2],[1,2,3]])  
plt.imshow(data,cmap="gray")



    
        #heatmap = ax.pcolor(data, cmap=plt.cm.binary)
        
        #ax.set_xticklabels(row_labels, minor=False)
        #ax.set_yticklabels(column_labels, minor=False)
#plt.show()

plt.show()
